# %% [markdown]
# #### CS20M059 Shibobrota Das | CS20M007 Abhishek Kumar

# %% [markdown]
# ## Setup

# %%
# !pip install tensorflow-addons -qqq
# Out:
#      |████████████████████████████████| 686kB 9.2MB/s eta 0:00:01

# %%
# !pip install wandb -qqq
# Out:
#      |████████████████████████████████| 1.8MB 8.4MB/s
#      |████████████████████████████████| 133kB 51.7MB/s
#      |████████████████████████████████| 174kB 38.2MB/s
#      |████████████████████████████████| 102kB 12.8MB/s
#      |████████████████████████████████| 71kB 8.2MB/s
#   Building wheel for subprocess32 (setup.py) ... done
#   Building wheel for pathtools (setup.py) ... done

# %%
import numpy as np
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
import tensorflow as tf
import tensorflow_addons as tfa
from tensorflow import GradientTape
from tensorflow import keras
import pandas as pd
import datetime
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.layers import Dense, Embedding, LSTM, GRU, SimpleRNN, SimpleRNNCell, LSTMCell, GRUCell
from keras.models import Sequential
from keras.losses import SparseCategoricalCrossentropy, CategoricalCrossentropy
import time
import sys
import datetime
from sklearn.utils import shuffle
import wandb
# import nltk
import csv
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from matplotlib.font_manager import FontProperties

print("Using numpy:",np.__version__)
print("Using tensorflow:",tf.__version__)
print("Using tensorflow Addons:",tfa.__version__)
print("Using keras:",keras.__version__)
print("Using pandas:",pd.__version__)
# Out:
# Using numpy: 1.19.5
# Using tensorflow: 2.5.0
# Using tensorflow Addons: 0.13.0
# Using keras: 2.5.0
# Using pandas: 1.2.4

# %%
# wandb.init(project='Assignment 3', entity='iitm-cs6910-jan-may-2021-cs20m059-cs20m007')
# Out:
# Finishing last run (ID:2ieo5mk6) before initializing another...
# ...Successfully finished last run (ID:2ieo5mk6). Initializing new run:<br/><br/>
#                 Tracking run with wandb version 0.10.30<br/>
#                 Syncing run <strong style="color:#cdcd00">crisp-water-211</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/iitm-cs6910-jan-may-2021-cs20m059-cs20m007/Assignment%203" target="_blank">https://wandb.ai/iitm-cs6910-jan-may-2021-cs20m059-cs20m007/Assignment%203</a><br/>
#                 Run page: <a href="https://wandb.ai/iitm-cs6910-jan-may-2021-cs20m059-cs20m007/Assignment%203/runs/6g6t6l2c" target="_blank">https://wandb.ai/iitm-cs6910-jan-may-2021-cs20m059-cs20m007/Assignment%203/runs/6g6t6l2c</a><br/>
#                 Run data is saved locally in <code>/content/drive/My Drive/A3-checkpoints/wandb/run-20210520_185916-6g6t6l2c</code><br/><br/>
# <h1>Run(6g6t6l2c)</h1><iframe src="https://wandb.ai/iitm-cs6910-jan-may-2021-cs20m059-cs20m007/Assignment%203/runs/6g6t6l2c" style="border:none;width:100%;height:400px"></iframe>

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd '/content/drive/My Drive/DL-A3 Dataset/dakshina_dataset_v1.0/hi/'
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/DL-A3 Dataset/dakshina_dataset_v1.0/hi

# %% [markdown]
# #### Load Data

# %%
val_df = pd.read_csv("./lexicons/hi.translit.sampled.dev.tsv", sep='\t', header=None)
train_df = pd.read_csv("./lexicons/hi.translit.sampled.train.tsv", sep='\t', header=None)
test_df = pd.read_csv("./lexicons/hi.translit.sampled.test.tsv", sep='\t', header=None)
print("Data Loaded to Dataframes!")
# Out:
# Data Loaded to Dataframes!

# %%
# %cd '/content/drive/My Drive/A3-checkpoints/'
# Out:
# /content/drive/My Drive/A3-checkpoints

# %% [markdown]
# #### Dataset Samples

# %%
train_df.sample(n=3)
# Out:
#               0          1  2
# 33464     राजीव      rajiv  4
# 5639   एतिहासिक  athihasik  1
# 7565     कामयाब     kamyab  4

# %% [markdown]
# ## Preparing Dataset

# %%
sos = "@"
eos = "#"

# %%
class LexDataset:
    def __init__(self, input_tensor, target_tensor, batch_size):
        self.input_tensor = input_tensor
        self.target_tensor = target_tensor
        self.batch = tf.data.Dataset.from_tensor_slices((self.input_tensor, self.target_tensor)).shuffle(len(self.input_tensor)).batch(batch_size, drop_remainder=True)

# %%
class TransliterationDatatset:
    def __init__(self, df_list, batch_size = 64):
        
        self.input_tokenizer = None
        self.target_tokenizer = None
        self.train = None
        self.val = None
        self.test = None
        self.batch_size = batch_size
        # Load Data
        self.load_dataset(df_list)
        # Other parameters
        self.num_input_tokens = len(self.input_tokenizer.index_word)+1
        self.num_target_tokens = len(self.target_tokenizer.index_word)+1
        self.max_input_seq_length = np.max([self.train.input_tensor.shape[1], self.val.input_tensor.shape[1], self.test.input_tensor.shape[1]])
        self.max_target_seq_length = np.max([self.train.target_tensor.shape[1], self.val.target_tensor.shape[1], self.test.target_tensor.shape[1]])
        
    def preprocess_word(self, w):
        return sos + str(w) + eos
    
    def print_input(self, tensor):
        for t in tensor:
            if t != 0:
                print(f'{t} ----> {self.input_tokenizer.index_word[t]}')
                
    def print_target(self, tensor):
        for t in tensor:
            if t != 0:
                print(f'{t} ----> {self.target_tokenizer.index_word[t]}')
    
    def create_dataset(self, data_frame):
        input_words = []
        target_words = []
        # Shuffle the data_frame before creating dataset
        df = data_frame
        for i in range(5):
            df = shuffle(df)
        for x, y in zip(df[1], df[0]):
            input_words.append(self.preprocess_word(x))
            target_words.append(self.preprocess_word(y))
        return (input_words, target_words)
    
    def load_dataset(self, df_list):
        # df_list should have train -> val -> test in sequence
        
        self.input_tokenizer = Tokenizer(num_words = None, char_level = True)
        self.target_tokenizer = Tokenizer(num_words = None, char_level = True)
        
        ds_list = []
        
        for df in df_list:
            # Get the words list
            (input_words, target_words) = self.create_dataset(df)
            # Fit on the set of words
            self.input_tokenizer.fit_on_texts(input_words)
            self.target_tokenizer.fit_on_texts(target_words)
            ds_list.append((input_words, target_words))
                    
        self.target_tokenizer.index_word.update({0:" "})
        self.input_tokenizer.index_word.update({0:" "})
        
        input_word_len = []
        target_word_len = []
        
        tensor_list = []
        
        for i, (input_words, target_words) in enumerate(ds_list):
            input_tensor = self.input_tokenizer.texts_to_sequences(input_words)
            target_tensor = self.target_tokenizer.texts_to_sequences(target_words)
            tensor_list.append((input_tensor, target_tensor))
            input_word_len.append(np.max([len(x) for x in input_tensor]))
            target_word_len.append(np.max([len(x) for x in target_tensor]))
        
        for i, (input_tensor, target_tensor) in enumerate(tensor_list):
            
            input_tensor = pad_sequences(input_tensor, padding='post', maxlen = np.max(input_word_len))
            target_tensor = pad_sequences(target_tensor, padding='post', maxlen = np.max(target_word_len))
            
            if i == 0:
                self.train = LexDataset(input_tensor, target_tensor, self.batch_size)
            elif i == 1:
                self.val = LexDataset(input_tensor, target_tensor, self.batch_size)
            else:
                self.test = LexDataset(input_tensor, target_tensor, self.batch_size)

# %%
dataset = TransliterationDatatset([train_df, val_df, test_df], 128)

# %% [markdown]
# #### Training Data

# %%
# Training data
dataset.train.input_tensor.shape, dataset.train.target_tensor.shape
# Out:
# ((44204, 22), (44204, 21))

# %% [markdown]
# #### Validation Data

# %%
# Validation data
dataset.val.input_tensor.shape, dataset.val.target_tensor.shape
# Out:
# ((4358, 22), (4358, 21))

# %% [markdown]
# #### Test Data

# %%
# Test data
dataset.test.input_tensor.shape, dataset.test.target_tensor.shape
# Out:
# ((4502, 22), (4502, 21))

# %% [markdown]
# #### Number of Tokens

# %%
# Number of tokens
dataset.num_input_tokens, dataset.num_target_tokens
# Out:
# (30, 67)

# %% [markdown]
# #### Maximum Sequence Lengths

# %%
# max seq length
dataset.max_input_seq_length, dataset.max_target_seq_length
# Out:
# (22, 21)

# %% [markdown]
# #### Example batch - dataset

# %%
example_input_batch, example_target_batch = next(iter(dataset.train.batch))
example_input_batch.shape, example_target_batch.shape
# Out:
# (TensorShape([128, 22]), TensorShape([128, 21]))

# %%
dataset.print_input(example_input_batch[2].numpy())
# Out:
# 2 ----> @
# 9 ----> s
# 1 ----> a
# 16 ----> m
# 17 ----> p
# 15 ----> u
# 7 ----> r
# 1 ----> a
# 4 ----> n
# 3 ----> #

# %%
dataset.print_target(example_target_batch[2].numpy())
# Out:
# 1 ----> @
# 9 ----> स
# 10 ----> ं
# 17 ----> प
# 29 ----> ू
# 4 ----> र
# 5 ----> ्
# 41 ----> ण
# 2 ----> #

# %% [markdown]
# ## Encoder and Decoder Model

# %%
class Encoder(tf.keras.Model):
    def __init__(self, vocab_size, embedding_dim, enc_units, batch_sz, layer_type="GRU"):
        super(Encoder, self).__init__()
        self.batch_sz = batch_sz
        self.enc_units = enc_units
        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
#         if layer_type == "LSTM":
        self.gru = tf.keras.layers.GRU(self.enc_units,
                                       return_sequences=True,
                                       return_state=True,
                                       recurrent_initializer='glorot_uniform')

    def call(self, x, hidden):
        x = self.embedding(x)
        output, state = self.gru(x, initial_state=hidden)
        return output, state

    def initialize_hidden_state(self):
        return tf.zeros((self.batch_sz, self.enc_units))

# %%
vocab_inp_size = dataset.num_input_tokens
embedding_dim = 64
units = 256
BATCH_SIZE = dataset.batch_size

# %%
encoder = Encoder(vocab_inp_size, embedding_dim, units, BATCH_SIZE)

# sample input
sample_hidden = encoder.initialize_hidden_state()
sample_output, sample_hidden = encoder(example_input_batch, sample_hidden)
print('Encoder output shape: (batch size, sequence length, units)', sample_output.shape)
print('Encoder Hidden state shape: (batch size, units)', sample_hidden.shape)
# Out:
# Encoder output shape: (batch size, sequence length, units) (128, 22, 256)
# Encoder Hidden state shape: (batch size, units) (128, 256)

# %%
class BahdanauAttention(tf.keras.layers.Layer):
    def __init__(self, units):
        super(BahdanauAttention, self).__init__()
        self.W1 = tf.keras.layers.Dense(units)
        self.W2 = tf.keras.layers.Dense(units)
        self.V = tf.keras.layers.Dense(1)

    def call(self, query, values):
        # query hidden state shape == (batch_size, hidden size)
        # query_with_time_axis shape == (batch_size, 1, hidden size)
        # values shape == (batch_size, max_len, hidden size)
        # we are doing this to broadcast addition along the time axis to calculate the score
        query_with_time_axis = tf.expand_dims(query, 1)

        # score shape == (batch_size, max_length, 1)
        # we get 1 at the last axis because we are applying score to self.V
        # the shape of the tensor before applying self.V is (batch_size, max_length, units)
        score = self.V(tf.nn.tanh(
            self.W1(query_with_time_axis) + self.W2(values)))

        # attention_weights shape == (batch_size, max_length, 1)
        attention_weights = tf.nn.softmax(score, axis=1)

        # context_vector shape after sum == (batch_size, hidden_size)
        context_vector = attention_weights * values
        context_vector = tf.reduce_sum(context_vector, axis=1)

        return context_vector, attention_weights

# %%
attention_layer = BahdanauAttention(10)
attention_result, attention_weights = attention_layer(sample_hidden, sample_output)

print("Attention result shape: (batch size, units)", attention_result.shape)
print("Attention weights shape: (batch_size, sequence_length, 1)", attention_weights.shape)
# Out:
# Attention result shape: (batch size, units) (128, 256)
# Attention weights shape: (batch_size, sequence_length, 1) (128, 22, 1)

# %%
class Decoder(tf.keras.Model):
    def __init__(self, vocab_size, embedding_dim, dec_units, batch_sz):
        super(Decoder, self).__init__()
        self.batch_sz = batch_sz
        self.dec_units = dec_units
        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
        self.gru = tf.keras.layers.GRU(self.dec_units,
                                       return_sequences=True,
                                       return_state=True,
                                       recurrent_initializer='glorot_uniform')
        self.fc = tf.keras.layers.Dense(vocab_size)

        # used for attention
        self.attention = BahdanauAttention(self.dec_units)

    def call(self, x, hidden, enc_output):
        # # enc_output shape == (batch_size, max_length, hidden_size)
        # context_vector, attention_weights = self.attention(hidden, enc_output)

        # x shape after passing through embedding == (batch_size, 1, embedding_dim)
        x = self.embedding(x)

        # # x shape after concatenation == (batch_size, 1, embedding_dim + hidden_size)
        # x = tf.concat([tf.expand_dims(context_vector, 1), x], axis=-1)

        # passing the concatenated vector to the GRU
        output, state = self.gru(x, initial_state = hidden)

        # output shape == (batch_size * 1, hidden_size)
        output = tf.reshape(output, (-1, output.shape[2]))

        # output shape == (batch_size, vocab)
        x = self.fc(output)

        # return x, state, attention_weights
        return x, state, None

# %%
vocab_tar_size = dataset.num_target_tokens

# %%
decoder = Decoder(vocab_tar_size, embedding_dim, units, BATCH_SIZE)

sample_decoder_output, _, _ = decoder(tf.random.uniform((BATCH_SIZE, 1)),
                                      sample_hidden, sample_output)

print('Decoder output shape: (batch_size, vocab size)', sample_decoder_output.shape)
# Out:
# Decoder output shape: (batch_size, vocab size) (128, 67)

# %% [markdown]
# ## Optimizer and the loss function

# %%
optimizer = tf.keras.optimizers.Adam()
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True,
                                                            reduction='none')


def loss_function(real, pred):
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    loss_ = loss_object(real, pred)

    mask = tf.cast(mask, dtype=loss_.dtype)
    loss_ *= mask

    return tf.reduce_mean(loss_)

# %%
def word_accuracy(real, pred):
    pass

# %% [markdown]
# ## Training

# %%
@tf.function
def train_step(inp, targ, enc_hidden):
    loss = 0

    with tf.GradientTape() as tape:
        enc_output, enc_hidden = encoder(inp, enc_hidden)

        dec_hidden = enc_hidden

        dec_input = tf.expand_dims([dataset.target_tokenizer.word_index[sos]] * BATCH_SIZE, 1)

        # Teacher forcing - feeding the target as the next input
        for t in range(1, targ.shape[1]):
            # passing enc_output to the decoder
            predictions, dec_hidden, _ = decoder(dec_input, dec_hidden, enc_output)

            loss += loss_function(targ[:, t], predictions)

            # using teacher forcing
            dec_input = tf.expand_dims(targ[:, t], 1)

    batch_loss = (loss / int(targ.shape[1]))

    variables = encoder.trainable_variables + decoder.trainable_variables

    gradients = tape.gradient(loss, variables)

    optimizer.apply_gradients(zip(gradients, variables))

    return batch_loss

# %%
EPOCHS = 1
steps_per_epoch = len(dataset.train.input_tensor)//BATCH_SIZE

for epoch in range(EPOCHS):
    start = time.time()

    enc_hidden = encoder.initialize_hidden_state()
    total_loss = 0

    for (batch, (inp, targ)) in enumerate(dataset.train.batch.take(steps_per_epoch)):
        batch_loss = train_step(inp, targ, enc_hidden)
        total_loss += batch_loss

        if batch % 100 == 0:
            print(f'Epoch {epoch+1} Batch {batch} Loss {batch_loss.numpy():.4f}')

    print(f'Epoch {epoch+1} Loss {total_loss/steps_per_epoch:.4f}')
    print(f'Time taken for 1 epoch {time.time()-start:.2f} sec\n')
# Out:
# Epoch 1 Batch 0 Loss 1.4859
# Epoch 1 Batch 100 Loss 0.9846
# Epoch 1 Batch 200 Loss 0.8932
# Epoch 1 Batch 300 Loss 0.9177
# Epoch 1 Loss 0.9682
# Time taken for 1 epoch 153.54 sec

# %% [markdown]
# ## Translate

# %%
def evaluate(sentence):
    attention_plot = np.zeros((dataset.max_target_seq_length, dataset.max_input_seq_length))

    sentence = dataset.preprocess_word(sentence)

    inputs = [dataset.input_tokenizer.word_index[i] for i in sentence]
    inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs],
                                                         maxlen=dataset.max_input_seq_length,
                                                         padding='post')
    inputs = tf.convert_to_tensor(inputs)

    result = ''

    hidden = [tf.zeros((1, units))]
    enc_out, enc_hidden = encoder(inputs, hidden)

    dec_hidden = enc_hidden
    dec_input = tf.expand_dims([dataset.target_tokenizer.word_index[sos]], 0)

    for t in range(dataset.max_target_seq_length):
        predictions, dec_hidden, attention_weights = decoder(dec_input,
                                                            dec_hidden,
                                                            enc_out)

        # # storing the attention weights to plot later on
        # attention_weights = tf.reshape(attention_weights, (-1, ))
        # attention_plot[t] = attention_weights.numpy()

        predicted_id = tf.argmax(predictions[0]).numpy()

        result += dataset.target_tokenizer.index_word[predicted_id]

        if dataset.target_tokenizer.index_word[predicted_id] == eos:
            # return result, sentence, attention_plot
            return result, sentence, None

        # the predicted ID is fed back into the model
        dec_input = tf.expand_dims([predicted_id], 0)

    # return result, sentence, attention_plot
    return result, sentence, None

# %%
# function for plotting the attention weights
def plot_attention(attention, sentence, predicted_sentence):
    fig = plt.figure(figsize=(10, 10))
    ax = fig.add_subplot(1, 1, 1)
    ax.matshow(attention, cmap='viridis')

    fontdict = {'fontsize': 14}

    hindi_font = FontProperties(fname = 'Nirmala.ttf')

    ax.set_xticklabels([''] + sentence, fontdict=fontdict, rotation=0)
    ax.set_yticklabels([''] + predicted_sentence, fontdict=fontdict, fontproperties=hindi_font)

    ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
    ax.yaxis.set_major_locator(ticker.MultipleLocator(1))
    input = ''.join([ch for ch in sentence])[1:-1]
    target = ''.join([ch for ch in predicted_sentence])[:-1]
    plt.title(f"Input: {input}  Prediction: {target}", fontproperties=hindi_font, fontsize = 20)
    plt.savefig(f"{input}.png")
    plt.show()

# %%
def translate(sentence):
    result, sentence, attention_plot = evaluate(sentence)

    print('Input:', sentence)
    print('Predicted translation:', result)

    attention_plot = attention_plot[:len(result),
                                  :len(sentence)]
    plot_attention(attention_plot, [i for i in sentence], [i for i in result])

# %%
translate("jaao")
# Out:
# Input: @jaao#
# Predicted translation: आयान#
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-257f19001a3f> in <module>
# ----> 1 translate("jaao")
#
# <ipython-input-46-a4cf7a66f42e> in translate(sentence)
#       5     print('Predicted translation:', result)
#       6
# ----> 7     attention_plot = attention_plot[:len(result),
#       8                                   :len(sentence)]
#       9     plot_attention(attention_plot, [i for i in sentence], [i for i in result])
#
# TypeError: 'NoneType' object is not subscriptable

# %%
sequence = dataset.input_tokenizer.texts_to_sequences("shibobrota")
np.reshape(sequence, len(sequence))
# Out:
# array([ 9,  6,  5, 19, 11, 19,  7, 11,  8,  1])

# %%
text = dataset.input_tokenizer.sequences_to_texts(sequence)
text
# Out:
# ['s', 'h', 'i', 'b', 'o', 'b', 'r', 'o', 't', 'a']

# %%
def save_predictions(data_frame, name):
    accuracy_count = 0;
    with open(name, 'w', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(["INPUT", "PREDICTION", "TRUE"])
        for i, (inp, trg) in enumerate(zip(data_frame[1], data_frame[0])): 
            result, sentence, attention_plot = evaluate(inp)
            writer.writerow([inp, result[:-1], trg])
            print(inp, result[:-1], trg)
            if result[:-1] == trg:
                accuracy_count += 1
            if (i+1) % 100 == 0 or i+1 == data_frame.size:
                print("Accuracy", (accuracy_count / (i+1)))

    return accuracy_count/data_frame.size

# %%
save_predictions(test_df, "new_without_attn_predictions.csv")
# Out:
# ank एंच अंक
# anka अंका अंक
# ankit अंक्षी अंकित
# anakon आंचो अंकों
# ankhon अंचों अंकों
# ankon अंकों अंकों
# angkor अंगूर्त अंकोर
# ankor अनफे अंकोर
# angaarak अंगारक अंगारक
# angarak अंगारक अंगारक
# angraji अंग्रजी अंग्रज़ी
# angreji अंग्रजी अंग्रज़ी
# angrzi अंग्रज अंग्रज़ी
# antah अंठा अंतः
# antaha अंठा अंतः
# antarmukh अंतर्विम अंतर्मुख
# antmurkh अंग्राउद्ध अंतर्मुख
# antrmukh अंतरगुहाओं अंतर्मुख
# andrabee अंदराबि अंद्राबी
# andrabi अंदराबि अंद्राबी
# andha अंधा अंधा
# andhapan अंधकाल अंधापन
# andheri अंगारू अंधेरी
# ambaani अम्माद अंबानी
# ambani अम्मेज अंबानी
# akram अक्रम अकरम
# acapulco अपैंकुप अकापुल्को
# akapulko अपाउछिप अकापुल्को
# akhand अखंज अखंड
# akhil अखिल अखिल
# agavai अगवाई अगवाई
# agvaai अगवाई अगवाई
# augustine ऑजिस्टिन अगस्टाइन
# augustustine ऑनुक्सिकेशन अगस्टाइन
# agsta अग्त्सा अगस्ता
# agusta अज्ञासत अगस्ता
# augusta ऑमकील्ट अगस्ता
# agr एग्र अग्र
# agra अगरा अग्र
# achambha अच्मयत अचंभा
# achanbha आचंग अचंभा
# achievement अशुमीरहीन अचीवमेंट
# achivement अशुद्मेंघ अचीवमेंट
# acchi आचिक अच्छी
# achchi आच्छि अच्छी
# achhi अच्छी अच्छी
# achyut अछूति अच्युत
# achhanera अच्छातों अछनेरा
# achnera अच्नारण अछनेरा
# ajmeedh अजमेगु अजमीढ़
# ajhar अहराज अजहर
# azhar अजहर अजहर
# ajit अजीत अजित
# agnat अग्नत अज्ञात
# agyaat अज्ञात अज्ञात
# agyat अज्ञत अज्ञात
# atakta आत्त्र अटकता
# atkata अत्काट अटकता
# atake आत्का अटके
# atke आत्क अटके
# atwaal अत्वाला अटवाल
# atwal अत्वल अटवाल
# attahasa अत्थालाप अट्टहास
# atthaas अत्थाला अट्टहास
# atthas अत्थाला अट्टहास
# addon अद्दों अड्डों
# athak आठक अथक
# atharv अठर्व अथर्व
# atharva अठर्वा अथर्व
# adad अदाद अदद
# adaani अदानी अदाणी
# adani अदानी अदाणी
# advait अद्वास अद्वैत
# adwait अद्वित अद्वैत
# advaitvaad अध्यारवाद अद्वैतवाद
# asamanjasya असमान्यताएं असामंजस्य
# asurakshit असुरक्षा असुरक्षित
# asurkshit असुरक्षित असुरक्षित
# aset एस्ट असेट
# asset एस्टेस असेट
# asvabhavik अस्वाभाविक अस्वभाविक
# aswabhavik अस्वाभाविक अस्वभाविक
# aswbhavik अस्वाभाविक अस्वभाविक
# ahirauli अहरियाल अहिरौली
# item इतनी आइटम
# items इत्मेस आइटम्स
# idle इडल आइडल
# idol इडोल आइडल
# icc आईसीसी आइसीसी
# iso आईएसए आइसो
# ipc आईपीएस आईपीसी
# ipad ईपाट आईपैड
# iris आईआरसी आईरिस
# ounce ऊंटे आउंस
# aakaash आकाश आकाश
# aakash आकाश आकाश
# aake आके आके
# aakhet आखेत आखेट
# akhet एक्ट आखेट
# aagat आग्त आगत
# aagaman आगमन आगमन
# aagman आगम्न आगमन
# aagaa आगा आग़ा
# aagah आगाह आग़ा
# agha अगहा आग़ा
# aagaashe आगाशी आगाशे
# aagashe आगाशी आगाशे
# agashe अगशे आगाशे
# aajmaanaa आमाजान्य आजमाना
# aajmana आजमान आजमाना
# aazmaanaa आजमाना आजमाना
# aata आता आटा
# ata अटा आटा
# atta अत्ता आटा
# aatmayen आत्मायन आत्माएं
# atmaen अत्मान आत्माएं
# aadaan आदान आदान
# aadan आदान आदान
# aadhaarit आधारिक आधारित
# aadharit आधारिक आधारित
# adharit अधारित आधारित
# aadheen आधेन आधीन
# aadhin आधान आधीन
# aadhunik अध्युनिक आधुनिक
# aanad आनंद आनद
# aanand आनंद आनद
# anand अनंज आनद
# aapka आपक आपका
# aapkaa आपका आपका
# aapadaaaen आपाधाएं आपदाएं
# aapdaein आपदाएं आपदाएं
# aapdayein आपात्मि आपदाएं
# aabantit आजमेटि आबंटित
# abantit अमातीगी आबंटित
# Accuracy 0.16333333333333333
# aabru आबड़ी आबरू
# abaru अबारू आबरू
# aamdan आमादन आमदन
# amadan अमाद्य आमदन
# aamdani आमादीन आमदनी
# amadani अमाद्यान आमदनी
# aamdi आमदी आमदी
# amdi अम्री आमदी
# aamod आमोड़ आमोद
# amod अमोड आमोद
# aayenge आयेंगे आयेंगे
# aayojak आयोग्या आयोजक
# ro राओ आरओ
# rp आरपी आरपी
# aaraam आराम आराम
# aaram आर्म आराम
# aram आर्म आराम
# aarushi आरिका आरुषि
# arushi अरुष्य आरुषि
# artery एर्टेरी आर्टरी
# order एरीडर आर्डर
# aary आर्ट आर्य
# aarya आराय आर्य
# arya अर्या आर्य
# aaryika आरिका आर्यिका
# aryika अरिका आर्यिका
# aarya आराय आर्यो
# arya अर्या आर्यो
# aryo अर्यू आर्यो
# aaryan आर्यान आर्यों
# arya अर्या आर्यों
# aryon अर्यन आर्यों
# aalsi आलसी आलसी
# alasi अलसी आलसी
# aalochak आलोचार आलोचक
# alochak अलोख्च आलोचक
# aalochakon आलोचालर आलोचकों
# alochakon अलोखों आलोचकों
# aalha आह्ला आल्हा
# aalhaa आह्ला आल्हा
# alha अलह आल्हा
# allah अल्हाल आल्हा
# aawaazen आवाजें आवाज़ें
# aawajen आवाजें आवाज़ें
# awaazen आवाजें आवाज़ें
# awazen आवाजें आवाज़ें
# aawajon आवाजों आवाज़ों
# aawazon आवाजों आवाज़ों
# awaazon अवजों आवाज़ों
# awazon अवजों आवाज़ों
# aavishakaar आविष्कार आविष्कार
# aavishkaar आविष्कार आविष्कार
# avishkar अविष्कार आविष्कार
# aavriti आवर्ती आवृत्ति
# aavritti आवर्तित आवृत्ति
# avuti अविज्ञ आवृत्ति
# aavritiyon आवर्तिनी आवृत्तियों
# aavrittiyon आवर्तितों आवृत्तियों
# avrutiyon अवरूति आवृत्तियों
# aashanka आशांक आशंका
# ashanka अशांख आशंका
# aashriton आश्रियों आश्रितों
# ashriton अश्रीयनों आश्रितों
# aasaan आसन आसान
# aasan आसन आसान
# asan आसन आसान
# aastik आस्तिक आस्तिक
# astik अस्तिक आस्तिक
# aasteen आस्तें आस्तीन
# aastin आस्ताने आस्तीन
# astin अस्तिन आस्तीन
# aahnaan आहनाम आह्नान
# aahnan आह्नाम आह्नान
# ahyan अहाँ आह्नान
# england अनगेंस इंग्लैंड
# engineer एंजीनीटिक इंजिनियर
# introduction इंट्रोविकिंग इंट्रोडक्शन
# insurance इन्फाइनर इंश्योरेंस
# ear ईआईआपओ इअर
# eyer ईयर इअर
# eon इओं इआन
# iaan इयान इआन
# ekattha इक्तता इकट्ठा
# ikattha इकत्यागा इकट्ठा
# ekatthi एकत्याद इकठ्ठी
# ekthi एक्ट्यू इकठ्ठी
# ikatthi इक्तियाश इकठ्ठी
# ekaee इकाई इकाई
# ikai इकाई इकाई
# ekaeyon इकाइयों इकाईयों
# ikaiyon इकाइयों इकाईयों
# ikarion इकरोसी इकाईयों
# economic इकोनॉमिक इकोनोमिक
# ecuador इकोड़र इक्वाडोर
# equador एकोडायर इक्वाडोर
# equities एकियाजिक इक्विटीज
# ikvitija इक्वित्व इक्विटीज
# ijaajat इजाज़त इजाजत
# ijajat इज़ाजत इजाजत
# inhalation इन्हालिक इनहेलेशन
# Accuracy 0.1475
# inhaletion इन्लाहिटियल इनहेलेशन
# ibija इबाइन इबीजा
# ibiza इबाइन इबीजा
# imaging इमागंद इमेजिंग
# immune इमिमों इम्युन
# elaichi एलियाड इलाइची
# ilaichi इलाउशिक इलाइची
# ilayachi इलायुक्त इलाइची
# ilayichi इलायुक्त इलाइची
# elaaj एलाम इलाज
# ilaaj इलाज इलाज
# ilaj इलाज इलाज
# ishaak इशाक इशाक
# ishaaq इशार इशाक
# ishak इशाक इशाक
# ishaara इशारा इशारा
# ishaaraa इशारा इशारा
# ishara इशारा इशारा
# ishita इश्ति इशिता
# isht इश्त इष्ट
# isteefe इस्तीपों इस्तीफे
# istife इस्तीफ इस्तीफे
# ea इय ईए
# ia इय ईए
# eater ईटार ईटर
# iter इतर ईटर
# email इमाले ईमेल
# emailon इमालों ईमेलों
# emelon इमोल ईमेलों
# evening इवेनॉन ईवनिंग
# east आईएसए ईष्ट
# ishat इशात ईष्ट
# isht इश्त ईष्ट
# isaaiyon इसाइयत ईसाइयों
# isaiyon इसाइयों ईसाइयों
# isayiyon इसाइयों ईसाइयों
# ikhrul इश्वुक उखरुल
# ukhrool उचरोप उखरुल
# ukhrul उच्फा उखरुल
# uchhalane उछलने उछालने
# uchhalne उछलने उछालने
# ujback उज्ज्वी उज़्बेक
# uzbek उजड़ी उज़्बेक
# uthane उठाने उठने
# uthne उगाने उठने
# uthaakar उठारक उठाकर
# uthakar उठारक उठाकर
# uthaapatak उत्कापय उठापटक
# uthapatak उत्काफार उठापटक
# uthen उठें उठें
# udaan उड़ना उड़ान
# udan उड़ना उड़ान
# udaanaa उदाना उड़ाना
# udana उड़ना उड़ाना
# udaane उड़ने उड़ाने
# udane उड़ने उड़ाने
# udaanen उड़ने उड़ानें
# udanen उड़ने उड़ानें
# udaanon उदानों उड़ानों
# udanon उड़ने उड़ानों
# utane उटने उतने
# utaney उतने उतने
# utne उटने उतने
# uttara उत्तर उत्तरा
# uttra उत्तर उत्तरा
# utpan उत्पन उत्पन
# udant उदान्य उदंत
# udghosh उद्घोष उदघोष
# udar उदार उदर
# uda उड़ा उदा
# udaa उड़ा उदा
# udakishuganj उद्यक्षिणिक उदाकिशुनगंज
# udakishunganj उद्यक्षिणिकों उदाकिशुनगंज
# unatees उन्मीसा उनतीस
# untees एजेट्स उनतीस
# uniyal उनुलीय उनियाल
# upadraviyon उपराजपति उपद्रवियों
# updravion उपरविदाय उपद्रवियों
# updraviyon उपरवियादी उपद्रवियों
# upadravi उपदारोती उपद्रवी
# updravi उपद्राफी उपद्रवी
# upadrawon उपराजवाद उपद्रवों
# updravon उपरविदा उपद्रवों
# upneta उसकने उपनेता
# upabhokta उपभाकेव उपभोक्ता
# upbhokta उपभाकेत उपभोक्ता
# uplaksh उपल्कशा उपलक्ष्य
# uplakshay उपलचापन उपलक्ष्य
# uplakshya उपल्कशाय उपलक्ष्य
# uplabdh उपन्यादार उपलब्ध
# uplabdhiyon उपन्यावसूर उपलब्धियों
# uplabdhi उपन्यादार उपलब्धी
# upakhyaanon उपचुलाव उपाख्यानों
# upakhyanon उपचुलाव उपाख्यानों
# ubuntu उम्दीय उबंटू
# ubaal उबाल उबाल
# ubal उबल उबाल
# ubhaara उभरा उभारा
# ubhara उभरा उभारा
# umanath उनमहास उमानाथ
# Accuracy 0.14
# umesh उम्जी उमेश
# urf ऊर्प उर्फ
# urfa यूराफ उर्फ
# urff आर्क उर्फ
# urvarakon अरुवर्कन उर्वरकों
# urvarkon अरुवर्कन उर्वरकों
# urwarakon अरुवर्कन उर्वरकों
# urvarata उर्वर्त उर्वरता
# urvarta उर्वर्त उर्वरता
# urwarta उर्वर्त उर्वरता
# ulate उलती उलटे
# ulte उलती उलटे
# ulahana उल्हाना उलाहना
# ulahna उल्हाना उलाहना
# ulema उलमे उलेमा
# ulemaon उल्मानी उलेमाओं
# usak उसक उसक
# usaki उसकी उसकी
# uski उस्की उसकी
# usmein उस्मेन उसमें
# usmen उस्मान उसमें
# usi उसी उसी
# ustara उस्त्र उस्तरा
# udharv उद्वार ऊर्ध्व
# udhrva उद्वावक ऊर्ध्व
# urdhav उर्धर ऊर्ध्व
# ushma उष्मा ऊष्मा
# rishicool ऋषिकों ऋषिकुल
# rishikul ऋषिकू ऋषिकुल
# rushikul ऋषिकाओं ऋषिकुल
# enzyme अन्मीयन एंजाइम
# anton अंटों एंटोन
# entone इंजेज़ एंटोन
# antoni अनादिन एंटोनी
# antony अन्यदन एंटोनी
# endometrial इंडोमेटिविस एंडोमेट्रियल
# andreas अंदरी एंड्रियास
# als एल्स एएलएस
# asi आसी एएसआई
# eksaath एक्साएं एकसाथ
# eksath एक्साएं एकसाथ
# ekaki एकिका एकाकी
# xm सीएमसी एक्सएम
# egmor एंडो एगमोर
# egmore एजमेड एगमोर
# aj अज एजे
# agende एजेंड एजेंडे
# adp एडपी एडीपी
# adain आदिन एडेन
# aden आड़ें एडेन
# edan इड़न एडेन
# addi अदृह एड्डी
# eddi एडीडी एड्डी
# eddie एडीडी एड्डी
# eddy एडीडी एड्डी
# apj अप्ट एपीजे
# ftii फटिए एफटीआईआई
# abbott एबडेब एबट
# abut एबीएड एबट
# ebt एम्ड एबट
# abvp एबपीडी एबीवीपी
# abbot एबबीट एबोट
# abbott एबडेब एबोट
# mta एमआईटी एमटीए
# mtake मटक एमटेक
# mtec मेट्स एमटेक
# mtech मेटक एमटेक
# emerald इमारेशी एमरल्ड
# emrald इमरसाइ एमरल्ड
# emil इमाल एमिल
# emile इमोले एमिल
# emily इमोली एमिल
# amy अम एमी
# emi एमी एमी
# airway एयरवाल एयरवे
# eyarave इयराड़ एयरवे
# eyarve इयरवा एयरवे
# error एरीराउप एरर
# arica आरिका एरिका
# erica एरिका एरिका
# erika एरिका एरिका
# aerobic एयरबेक एरोबिक
# aerobics एयरोडीज एरोबिक
# lte लेड एलटीई
# lti लिटी एलटीई
# allergic एलेश्विक एलर्जिक
# eliminator इलिजिमेटर एलिमिनेटर
# aliens एलायटें एलियंस
# alliance अल्लिंकन एलियंस
# asian असीन एशियन
# sfc एसएस एसएफसी
# sk एसएस एसके
# spf सीप्टी एसपीएफ
# association एसोसिएशन एसोसिएशन
# astar अस्त्र एस्टर
# aster अस्त्री एस्टर
# ester एस्टर एस्टर
# aesthetics एस्टेहिसिस एस्थेटिक
# asthetic अस्थितिय एस्थेटिक
# asfalt अस्क्षा एस्फाल्ट
# Accuracy 0.13
# asphalt अस्काच एस्फाल्ट
# asphault अस्फायक एस्फाल्ट
# ahsaas अहसास एहसास
# ehsaas अनकेल एहसास
# ehsas अनके एहसास
# aisa आईश एेसा
# eesa ईएसए एेसा
# ainth आनिजा ऐंठ
# end एंड ऐंठ
# enth एन्ड ऐंठ
# ainthey अनिथय ऐंठे
# enthe एंटो ऐंठे
# aithan ऐंठन ऐठन
# ethan ऐंठन ऐठन
# ethhan ऐंठन ऐठन
# ail आईल ऐल
# el एल ऐल
# alaps अल्प्स ऐल्प्स
# alps एल्प्स ऐल्प्स
# aise आईएसए ऐसे
# oxide ऑस्किट ऑक्साइड
# gaytri ज्ञादित गायत्री
# gidgidate गिडिंग्ड गिड़गिड़ाते
# ginate गिनते गिनते
# ginte गिनते गिनते
# girkar गिरक्तर गिरकर
# girijaghar गिरिंचर गिरजाघर
# girjaghar गिरग्नावास गिरजाघर
# girijagharon गिरिचंबल गिरजाघरों
# Accuracy 0.145
# girjagharon गिरधनशारा गिरजाघरों
# girati गिरती गिरती
# girti गिरती गिरती
# girish गिरिलत गिरीश
# guan गुण गुआन
# gujar गुजर गुजार
# gujarata गुजरता गुजारता
# gujarta गुजरता गुजारता
# gujarate गुजरते गुजारते
# gujarte गुजरते गुजारते
# gujarana गुजराना गुजारना
# gujarna गुजराना गुजारना
# gujara गुजरा गुजारा
# gujare गुजरे गुजारे
# gutta गुट्टा गुट्टा
# gthalidar ग्लाइजर गुठलीदार
# guthalidar गुणिकाशक गुठलीदार
# gudna गुड़ना गुदना
# gumaan गुमान गुमान
# guman गुमन गुमान
# gulshan गुलशन गुलशन
# gunga गुंजा गूंगा
# grihnagar ग्रीनगढ़ गृहनगर
# gruhnagar ग्रीघांज गृहनगर
# galaxion गैलकीज गैलेक्सियों
# galaxiyon गैलकीशन गैलेक्सियों
# galaxyon गलचित्यों गैलेक्सियों
# gochar गोचार गोचर
# gouchar गोहार्ल गोचर
# godara गोड़रा गोदारा
# gopichand गोपिंकर गोपीचंद
# gomake गोमाकी गोमके
# gomke गोंड गोमके
# goel गोल गोयल
# goyal गोला गोयल
# gosvaami गोस्थब गोस्वामी
# gosvami गोस्वामी गोस्वामी
# goswami गोस्वामी गोस्वामी
# gaumukh गुमाचू गौमुख
# gomukh गुंवों गौमुख
# gaumutr जुमागर गौमूत्र
# gaumutra जुमागरी गौमूत्र
# gowmutra जुभ्रणित गौमूत्र
# granthiyaan ग्रान्यागियों ग्रंथियां
# granthiyan ग्रांजिलाइयों ग्रंथियां
# grandhiyon ग्रांगुणिक ग्रंथियों
# granthiyon ग्रांजिल्न ग्रंथियों
# greest ग्रीस ग्रीस्ट
# greist ग्रिस्ट ग्रीस्ट
# grist ग्रीस ग्रीस्ट
# greg ग्रें ग्रेग
# granite ग्रेनेमिया ग्रेनाइट
# grenite ग्रेनीटी ग्रेनाइट
# grandson ग्रेंजेक्ट ग्रैंडसन
# gross ग्रीकल ग्रॉस
# ghataatop घटापत घटाटोप
# ghatatop घटापत घटाटोप
# ghataayaa घटाए घटाया
# ghataya घटाए घटाया
# ghanakar घंटकार घनाकार
# ghabrahat घबराजा घबराहट
# ghasi घटी घासी
# ghisai गलिता घिसाई
# ghisi ग्लाईड घिसी
# ghise घीसे घिसे
# ghumakkadi घुमाकुपार घुमक्कड़ी
# ghumakkdi घुमाक्रिया घुमक्कड़ी
# ghumakkadon घुमकोस्याबा घुमक्कड़ों
# ghumakkaron घुमकोर्थी घुमक्कड़ों
# ghumakkdon घुमकुरहिन घुमक्कड़ों
# ghummakkadon घुमानुद्वक घुमक्कड़ों
# ghumaan घूमना घुमाण
# ghuman घूमना घुमाण
# ghoonsa घोंका घूंसा
# jvar ज्वार ज्वार
# jwar ज्वार ज्वार
# jvaaron जरवान ज्वारों
# jvaron जरवान ज्वारों
# jwaron जर्वन ज्वारों
# jewellers जीवलेर्ल ज्वेलर्स
# jh झ झ
# jha झा झ
# jhalakti झलकती झलकती
# jhalkati झलकती झलकती
# jhalla झलाला झल्ला
# jhankana झंशाने झांकना
# jhankna झंशन झांकना
# jheel झेले झील
# jhil झिल झील
# jheelon झेलों झीलों
# jhilon झिलों झीलों
# jhuthala झुठाला झुठला
# jhuthla झुठला झुठला
# jhuthalane झुठलाने झुठलाने
# jhuthlane झुठलाने झुठलाने
# tankaar टांकर टंकार
# tankar टंकर टंकार
# takara टकरा टकरा
# takra टकरा टकरा
# takaraon तकराज टकरावों
# takravon तार्थारण टकरावों
# tapakti तपस्की टपकती
# tapkati तपस्की टपकती
# time टीमी टाइम
# timer टिम्ड टाइमर
# taoo टू टाऊ
# Accuracy 0.162
# tau ताऊ टाऊ
# tapoowo तापूर टापुओं
# tapuon तापूण टापुओं
# tapuwo तापुओव टापुओं
# tied टीड टायर्ड
# tired टीरेज टायर्ड
# tyred ट्यूटर टायर्ड
# tarch तार्च टार्च
# torch टॉर्च टार्च
# tik टीक टिक
# teap टीप टिप
# tip टीप टिप
# tippanikar टिप्पनाइक टिप्पणीकार
# tippnikar टिप्पनाइक टिप्पणीकार
# tivolee ट्यूज़ोज टिवोली
# tivoli टिविला टिवोली
# teekamgarh टीकमाचार टीकमगढ़
# tikamgarh टीकमांडर टीकमगढ़
# teekon टीकों टीकों
# tikon टिकों टीकों
# two ट्वू टु
# tension टेनीशन टेंशन
# tenis टीनेस टेनिस
# tennis टेनिंग टेनिस
# taste टकते टेस्ट
# test टेक्ट टेस्ट
# tasting तस्तंत टेस्टिंग
# testing टेक्टिंग टेस्टिंग
# tainin तैनी टैनिन
# tenin तेनियां टैनिन
# tanish तैनाथी टैनिस
# tennis टेनिंग टैनिस
# taboo तबिया टैबू
# taiboo तैबू टैबू
# taobao तिवा टैबू
# tonic टोनी टॉनिक
# tonga टोंगा टोंगा
# toka टोक टोका
# tuesday टुटकते ट्यूजडे
# tuning टाइनं ट्यूनिंग
# tuberculosis ट्वायोग्रोजिक ट्यूबरक्यूलोसिस
# tuberkyulosis तर्मोपक्षित ट्यूबरक्यूलोसिस
# truck ट्रॉक्स ट्रक
# trangistor ट्रांजीक्शन ट्रांजिस्टर
# tranjister ट्रांजीकर्स ट्रांजिस्टर
# transistor ट्रांसीटेंट ट्रांजिस्टर
# transfer ट्रांसफर ट्रान्सफर
# tribunal ट्रिमिव ट्रिब्युनल
# tribunal ट्रिमिव ट्रिब्यूनल
# trubyunal त्रुमुवान ट्रिब्यूनल
# truth त्रुष्ट ट्रुथ
# tuth तुथ ट्रुथ
# traded ट्रेड्ड ट्रेडेड
# trabal ट्रांड ट्रेबल
# trebal ट्रेड ट्रेबल
# trouble ट्रॉमर ट्रेबल
# traip ट्रिप ट्रैप
# trap ट्राफ ट्रैप
# trot ट्रॉट ट्रॉट
# thaanvi ठांगी थानवी
# thanvi ठंडो थानवी
# theateron थेटोरों थिएटरों
# theatron थैंपत थिएटरों
# theaters थैटर थिएटर्स
# theater थेटर थियेटर
# theatre ठेटर थियेटर
# theateron थेटोरों थियेटरों
# theatron थैंपत थियेटरों
# thitron थिट्रोहा थियेटरों
# theaters थैटर थियेटर्स
# theatrs ठेटर थियेटर्स
# thiyeters थियस्त्र थियेटर्स
# thirake थिरका थिरके
# thirke थिरकी थिरके
# thief थियर थीफ
# then थेन थेन
# theni थेनी थेनी
# thailee थाली थैली
# thaili थाली थैली
# thaile थाली थैले
# dang डंग दंग
# danga दंगा दंगा
# dangon डंगन दंगों
# dampati दामपति दंपति
# danpati दानपति दंपति
# dampatiyon दात्तिवास दंपतियों
# dampattiyon दात्तिवारी दंपतियों
# danptiyon डांपटेश दंपतियों
# dadreva दरड़ाज़ ददरेवा
# dadrewa दरड़ाजे ददरेवा
# damoh दमू दमोह
# dardara दरतराज दरदरा
# dardraa दरदारा दरदरा
# durdhara दुर्धारा दरदरा
# darmiyaan दरमियानी दरमियान
# darmiyan दरमियानी दरमियान
# darjano दर्जन्य दर्जनों
# darjanon दरणोखन दर्जनों
# darp दर्प दर्प
# darra दर्रा दर्रा
# dalbadal दलबाड़े दलबदल
# dalbadl दलवातें दलबदल
# dali दली दली
# dastaanaa दस्ताना दस्ताना
# dastana दस्तान दस्ताना
# dastavej दस्तावेज़ दस्तावेज
# dahan दाहन दहन
# Accuracy 0.15166666666666667
# dahal दहल दहल
# da डा दा
# daakhil दकोला दाखिल
# dakhil दखील दाखिल
# daakhile दफनी दाखिले
# dakhile दखीला दाखिले
# daataa दाता दाता
# data दाता दाता
# dadari दारादी दादरी
# daanshil दानसनी दानशील
# danshil डंशन दानशील
# daabholkar दावनियार दाभोलकर
# dabholkar दावनियार दाभोलकर
# damale दमले दामले
# damle डमल दामले
# dayitv दयित्त दायित्व
# dayitva दयात्राओं दायित्व
# dayitwa दयात्र दायित्व
# dayitvon टूड़ेंटे दायित्वों
# dayityon दायित्व दायित्वों
# darul दरिया दारूल
# daav दाव दाव
# daaw दाव दाव
# dav दाव दाव
# daw दाव दाव
# daah दाह दाह
# dah दाह दाह
# dikhla दिखला दिखला
# dikhlaa दिखला दिखला
# dikhaaiye दिखाइए दिखाइये
# dikhaiye दिखाइए दिखाइये
# dikhaai दिखाई दिखाई
# dikhai दिखाई दिखाई
# dikhayi दिखाइए दिखाई
# dikhaaee दिखाईए दिखाईं
# dikhaai दिखाई दिखाईं
# dikhaain दिखाएं दिखाईं
# dikhaee दिखाई दिखाईं
# dikhai दिखाई दिखाईं
# dikhayin दिखाइएं दिखाईं
# dikhai दिखाई दिखायी
# dikhayi दिखाइए दिखायी
# dikhaai दिखाई दिखार्इ
# dikhae दिखाई दिखार्इ
# dikhai दिखाई दिखार्इ
# dikhayi दिखाइए दिखार्इ
# dita दिता दिता
# ditaa दिता दिता
# dinaank दिनहेश दिनांक
# dinank डिनाश दिनांक
# dirham दिवात दिरहम
# narsanharon नरसंचार नरसंहारों
# november नॉबेंडर नवंबर
# navketan नवस्थी नवकेतन
# navjaagaran नवागाहाराज नवजागरण
# navjagran नवजंदर नवजागरण
# navdha नवादाह नवधा
# navvadhoo नववावों नववधू
# navvadhu नववावी नववधू
# nava नावा नवा
# navaa नवा नवा
# navate नवाते नवाते
# navanagar नवनगढ़ नवानगर
# nawanagar नवनागढ़ नवानगर
# navya नवा नव्या
# naseem नसीम नसीम
# nasim नस्मी नसीम
# nights नाइट्स नाइट्रस
# nitrous नित्रोष नाइट्रस
# nineteez नीनीट्ट नाइनटीज
# nineties नीनीटिक नाइनटीज
# ninties निंटिक नाइनटीज
# nau नौ नाऊ
# nauu नौऊ नाऊ
# naakaam नाकाम नाकाम
# nakam नकम नाकाम
# naagrik नागरिक नागारिक
# nagarik नगरीक नागारिक
# nagrik नगरीक नागारिक
# nagin नागीन नागिन
# nadep नेड्स नाडेप
# nanak नांच नानक
# nanavati नानावासी नानावती
# napane नापने नापने
# napne नेकाल नापने
# napa नापा नापा
# naam नाम नाम
# naamdhari नामदार नामधारी
# namdhari नामदार नामधारी
# namankano नमानकों नामांकनों
# namankanon नमानसों नामांकनों
# namavaliyon नमावशील नामावलियों
# naamo नामो नामो
# namo नम नामो
# nayak नायक नायक
# naraji नाराजी नाराजी
# naraingarh नरणीकर नारायणगढ़
# narayangadh नरणीखर नारायणगढ़
# narayangarh नरणीकरण नारायणगढ़
# naasar नासर नासर
# nahargadh नहर्नवाद नाहरगढ
# nahargarh नहरहादार नाहरगढ
# nikalegi निकालेगी निकलेगी
# nikalogi निकालेगी निकलेगी
# nikaalani निकालना निकालनी
# nikaalni निकालने निकालनी
# nikalani निकालने निकालनी
# nikalni निकलनी निकालनी
# nicki निक्सी निकी
# nicky निक्स निकी
# niki निकी निकी
# niketan निकटने निकेतन
# nikhar निचर निखर
# nikhari निचारी निखरी
# nigar निगर निगर
# nigger निगंडी निगर
# nichala निचला निचला
# nichalaa निचला निचला
# nichla निचला निचला
# nitiyon नितियों नितियों
# nitya नित्य नित्या
# nityaa नित्य नित्या
# nidhaan निधान निधान
# nidhan निधान निधान
# Accuracy 0.15761904761904763
# nipatara निपटारा निपटारा
# niptaara निपटारा निपटारा
# niptaaraa निपटारा निपटारा
# niptara निपटारा निपटारा
# niyanta नियमाना नियंता
# niyantaa नियमाना नियंता
# niya निया निया
# niyaa निया निया
# nirdeshika निर्देशकीय निर्देशिका
# nirdeshikaa निर्दस्थित निर्देशिका
# nirdhaarit निर्धारित निर्धारित
# nirdharit निर्धरता निर्धारित
# nirbaadh निर्मारी निर्बाध
# nirbadh निर्भर निर्बाध
# niveshakartaa निवासाधिकार निवेशकर्ता
# niveshkarta निवासाधिक निवेशकर्ता
# niveshkartaa निवासाध्यक्ष निवेशकर्ता
# nischal निष्कल निश्चल
# nishchal निष्चा निश्चल
# nishnaat निश्नत निष्णात
# nishpaap निष्प्र निष्पाप
# nihalaani निहालयां निहलानी
# nihlaani न्हालियां निहलानी
# suction सूस्तों सक्शन
# sacchidanand साक्ष्मीकरण सच्चिदानंद
# sachhidanand सचागंधी सच्चिदानंद
# sachidanand साकंभिक सच्चिदानंद
# sajja सजाज़ सज्जा
# sat सात सत
# satpal सत्पाल सतपाल
# satluj सत्यशन सतलुज
# sataane सटने सताने
# satane सटने सताने
# sate सटी सते
# satti सत्ती सत्ती
# satvat सत्वत सत्वत
# sadanand सादगनी सदानंद
# sapane सपने सपने
# sapne सपेना सपने
# sapney सपेंग सपने
# saparivaar सप्रबार सपरिवार
# sapariwar सप्रबार सपरिवार
# sparivar स्प्रॉइडर सपरिवार
# sapaat सपाट सपाट
# sapat सपाट सपाट
# sapate सपटे सपाटे
# sapatey सपेटा सपाटे
# saptakranti सप्तऋषित सप्तक्रांति
# saptkraanti सप्तऋषित सप्तक्रांति
# saptapadi सप्तऋष सप्तपदी
# saptpadi सप्तऋष सप्तपदी
# saptari सप्तरी सप्तरी
# sapramaan सप्रमान सप्रमाण
# sapraman सप्रमन सप्रमाण
# submit सब्जियम सबमिट
# sabmission सब्जियस्थ सबमिशन
# submission सब्जियस्थ सबमिशन
# sabhaein सभानी सभाएं
# sabhaen सभान सभाएं
# sabhayen सभाएं सभाएं
# sabhen साभेग सभाएं
# sabhasadon सभाकबानी सभासदों
# sabhyata सभ्यता सभ्यता
# samjhoonga समझुन्हा समझूंगा
# samjhunga समझुन्हा समझूंगा
# samjhungaa समझुन्हाय समझूंगा
# saman समान समन
# samanvayaka समन्वयव समन्वयक
# samanwayaka समन्वयत समन्वयक
# samnvyak संभाल्प समन्वयक
# samaadhaan समाधाओं समाधान
# samadhan समाधन समाधान
# samadhiyon समाधियों समाधियों
# samadjiyon समादिगों समाधियों
# samalakha समालाखे समालखा
# samalakhaa समालाखा समालखा
# samahaar समाहर समाहार
# samahar समहर समाहार
# samitiyan समीतियां समितियां
# sametati समीतता समेटती
# sametti समीटी समेटती
# sarka सरक सरका
# sarkaa सरकाल सरका
# sarkarein सरकारी सरकारें
# sarkaren सरकारी सरकारें
# sarkaaron सरकारों सरकारों
# sarkaron सरकारों सरकारों
# Accuracy 0.17
# sargana सर्जना सरगना
# sarganaon सर्जनाम सरगनाओं
# sargi सार्जी सरगी
# sarguja सार्जिक सरगुजा
# sarjuga सार्जिक सरगुजा
# sarsa सर्स सरसा
# sarsaa सरसाय सरसा
# sarahind सारंगि सरहिंद
# sarhind साधिक्त सरहिंद
# sirhind सिरंगिया सरहिंद
# saraaha सराह सराहा
# saraha सराह सराहा
# saraahi सराही सराही
# sarahi सार्य सराही
# salaahkar सलाखार सलाहकार
# salahkaar सलाखार सलाहकार
# salahkar सलाखार सलाहकार
# saleeb सैंती सलीब
# salib सैंसी सलीब
# select सेल्स सलेक्ट
# saltanat सालतंज सल्तनत
# saltnat सालतंज सल्तनत
# savaal सवाल सवाल
# saval सवल सवाल
# sawaal सावल सवाल
# sawal सवल सवाल
# sahakalaakar सहकाशकों सहकलाकार
# sahakalakar सहकाशक सहकलाकार
# sahkalakar सचहार्श सहकलाकार
# sugamata सुमात्मा सुगमता
# sugmta सुमतम्न सुगमता
# sujan सुमाल सुजेन
# sujen सूजने सुजेन
# suken सूकने सुजेन
# sujain सूजन सुजैन
# sujhaati सुझाड़े सुझाती
# sujhati सुझाड़े सुझाती
# sutali सुतली सुतली
# sutli सुटिला सुतली
# suta सूता सुता
# sdueep स्डिअर सुदीप
# sudip सूतिर सुदीप
# sudhaargrah सुधारगढ़ सुधारगृह
# sudhargrih सुधारगढ़ सुधारगृह
# sudhargruh सुधारगढ़ सुधारगृह
# sunaaron सुनारों सुनारों
# sunaron सुनरों सुनारों
# sunaseer सुनसीरा सुनासीर
# sunasir सुनिकर सुनासीर
# suneeti सुनीती सुनीति
# suniti सुनिति सुनीति
# sunega सुनेगा सुनेगा
# suneyga सुनेंटा सुनेगा
# superhit सूपरियां सुपरहिट
# supachy सूपूछा सुपाच्य
# supachya सूपछा सुपाच्य
# supachye सूपूछी सुपाच्य
# subhaay सुभाई सुभाय
# subhay सुभा सुभाय
# surveen सर्वें सुरवीन
# survin सुर्वि सुरवीन
# surana सूरना सुराणा
# sulkhan सुलझल सुलखान
# suljaayi सुलझी सुलझाई
# suljayi सुलझी सुलझाई
# suljhai सुलझा सुलझाई
# sulzai सुलझी सुलझाई
# sultana सुल्मासा सुलताना
# sulaati सुलाती सुलाती
# sulati सुलाती सुलाती
# susanskrit साइक्सीपेंड सुसंस्कृत
# susanskrut सिकंसपत्रों सुसंस्कृत
# suhagin सुहिग्ध सुहागिन
# soond सूंब सूंड़
# sund सुंड सूंड़
# suiyan सूइयां सूइयां
# sukhati सुखदे सूखती
# sukhti सुखती सूखती
# sukhakar सुखाकर सूखाकर
# soochak सौचाक सूचक
# suchak सूचक सूचक
# sooja सूझे सूजा
# suja सुमा सूजा
# suba सूबा सूबा
# sube सूबी सूबे
# sooraj सूर्य सूरज
# suraj सुराज़ सूरज
# surinaam सूर्यमण सूरीनाम
# surinama सुर्जिन सूरीनाम
# suriname सूर्यमंत सूरीनाम
# suryadev सूर्यावेद सूर्यदेव
# sendha सेंध सेंधा
# senvai सेंहर सेंवई
# sevai सेवी सेंवई
# sensing सेंसिंग सेंसिंग
# sexual सिक्कों सेक्सुअल
# saturday सत्रुध्य सेटरडे
# seti सीते सेटी
# seto सीते सेटो
# seth सेठ सेथ
# safety सफेती सेफ्टी
# semen सीमें सेमिन
# semin सीमें सेमिन
# Accuracy 0.16697674418604652
# self सेल्फ सेल्फ
# selfie सेल्फी सेल्फी
# save सावे सेव
# sev सेव सेव
# sevakon सेवाची सेवकों
# sevkon सेवकों सेवकों
# samuels समूल्स सैम्युल्स
# celery सेल्विक सैलरी
# salary सालारा सैलरी
# sakar साकार सॉकर
# socar सोकर सॉकर
# soccer सॉक्स सॉकर
# songs संग्स सॉन्ग्स
# solicitor सोल्टिकिंग सॉलिसिटर
# sochane सोचने सोचने
# sochne सोचने सोचने
# sonu सोनो सोनू
# soma सोमा सोमा
# spma स्पाम सोमा
# somi सोमी सोमी
# soy सो सोय
# soya सोया सोया
# solitaire सोल्टीजिट सोलिटेयर
# soharai सोहराए सोहराई
# sohrai सोहरा सोहराई
# sohaval सोहावे सोहावल
# sohawal सोहावे सोहावल
# saunpane सौंसाजे सौंपने
# sonpne सोनेक्ट सौंपने
# scala स्केल स्काला
# skala स्काला स्काला
# ski सीएसएस स्की
# scootaron सिक्योरमैन स्कूटरों
# scooteron सिक्योरिंग स्कूटरों
# skootaron सिक्रोणिया स्कूटरों
# scandinavia स्केमिंदर स्कैंडिनेविया
# scaining स्कीनिंग स्कैनिंग
# scanning स्केनिंग स्कैनिंग
# squash स्कूटा स्क्वाश
# squash स्कूटा स्क्वैश
# skhalan स्कषण स्खलन
# stain स्टेन स्टैन
# stan स्टान स्टैन
# stop स्टीप स्टॉप
# stops स्टॉप स्टॉप्स
# stone स्टोन स्टोन
# straws स्त्राव स्ट्रास
# stress स्ट्रिक स्ट्रास
# stra स्ट्री स्ट्रे
# stray स्त्रीय स्ट्रे
# stre स्ट्री स्ट्रे
# strocks स्ट्रॉक्स स्ट्रोक्स
# strokes स्ट्रॉक्स स्ट्रोक्स
# stan स्टान स्तन
# stanadhari स्तनावृत स्तनधारी
# standhaari स्तंधकों स्तनधारी
# standhari स्तंधक स्तनधारी
# sthiti स्थिति स्तिथि
# stithi स्तिजिय स्तिथि
# stuti स्टीविया स्तुति
# sthitiyaan स्थितियां स्थितियां
# sthitiyan स्थितियां स्थितियां
# sthitiyon स्थितियों स्थितियों
# sthool स्थुआल स्थूल
# sthul स्थुल स्थूल
# sthoolta स्थूनली स्थूलता
# sthulata स्थिलाय स्थूलता
# sneakers स्नेप्टर स्नीकर्स
# snickers सिंक्सप्र स्नीकर्स
# snikarse सिंकसर स्नीकर्स
# spear स्पाइड स्पीयर
# spell स्पाइल स्पेल
# spelar स्पेलर स्पेलर
# speller स्पेलिट स्पेलर
# sprint स्प्रिंट स्प्रिट
# sprit स्प्रिट स्प्रिट
# spray स्प्री स्प्रे
# spry स्प्री स्प्रे
# sfoorti स्फूर्ती स्फूर्ति
# sfurti स्फ्रिव स्फूर्ति
# sphoorti स्फीवारी स्फूर्ति
# slide स्लीड स्लाइड
# slider सिल्ट्री स्लाइडर
# slaaidon स्लेटों स्लाइडों
# slidon सिल्मर स्लाइडों
# sliders स्लीडर स्लाइड्स
# slides स्लीटर स्लाइड्स
# slice स्लिक स्लाइस
# slash स्लाश स्लैश
# swaroopon स्वरूपों स्वरुपों
# swarupon स्वरूपों स्वरुपों
# swa एसवे स्वा
# swaachaalit स्वाच्छित स्वाचालित
# swachalit स्वचालित स्वाचालित
# swaarthparak स्वारात्कारक स्वार्थपरक
# swarthparak स्वरक्षार्प स्वार्थपरक
# swiftlate स्वीकाशक स्विफ्टलेट
# swiftlet स्वीकाशक स्विफ्टलेट
# sweekarte स्वीकारती स्वीकारते
# swikarte स्वीकारत स्वीकारते
# Accuracy 0.1668181818181818
# sweet स्वीत स्वीट
# sweep स्वीप स्वीप
# sweccha स्वेच्छा स्वेच्छा
